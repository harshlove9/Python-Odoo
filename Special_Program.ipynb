# %%
grocery_item={}

grocery_history=[]

stop='go'

while stop != 'q':
    item_name=input("item name:\n")
    
    quantity=input('Quantity purshed:\n')
    
    cost=input('price per item:\n')
   
     #UPDATE
    
    grocery_item['name']=item_name
    grocery_item['number']=int(quantity)
    grocery_item['price']=float(cost)
    
    
    grocery_history.append(grocery_item.copy())
    
    stop=input('would you like to enter item?\n Type c for continue or q to quit:\n ')
        
    
        
grand_total=0

for index, item in enumerate(grocery_history):
    
    item_total=item['number'] * item['price']
    
    grand_total+=item_total
    
    print('%d %s  $%.2f ===== $%.2f'%(item['number'], item['name'],item['price'], item_total))
    
    item_total=0
    
print('grand total :$%.2f '% grand_total)
# Out:
# item name:
# apple
# Quantity purshed:
# 4
# price per item:
# 10
# would you like to enter item?
#  Type c for continue or q to quit:
#  c
# item name:
# kiwi
# Quantity purshed:
# 6
# price per item:
# 20
# would you like to enter item?
#  Type c for continue or q to quit:
#  c
# item name:
# mango
# Quantity purshed:
# 8
# price per item:
# 22
# would you like to enter item?
#  Type c for continue or q to quit:
#  c
# item name:
# grapes
# Quantity purshed:
# 10
# price per item:
# 40
# would you like to enter item?
#  Type c for continue or q to quit:
#  c
# item name:
# chiku
# Quantity purshed:
# 12
# price per item:
# 18
# would you like to enter item?
#  Type c for continue or q to quit:
#  q
# 4 apple  $10.00 ===== $40.00
# 6 kiwi  $20.00 ===== $120.00
# 8 mango  $22.00 ===== $176.00
# 10 grapes  $40.00 ===== $400.00
# 12 chiku  $18.00 ===== $216.00
# grand total :$952.00
